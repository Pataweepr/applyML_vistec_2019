# %% [markdown]
# <a href="https://colab.research.google.com/github/Pataweepr/applyML_vistec_2019/blob/master/howToLoadDataWPyDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## How to load data from  Google drive !!!
#
# 1.find folder ID
# 2.run this code

# %%
#@title
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# PyDrive reference:
# https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html

# 2. Create & upload a file text file.
#uploaded = drive.CreateFile({'title': 'Sample upload.txt'})
#uploaded.SetContentString('Sample upload file content')
#uploaded.Upload()
#print('Uploaded file with ID {}'.format(uploaded.get('id')))

# 3. Load a file by ID and print its contents.
#downloaded = drive.CreateFile({'id': uploaded.get('id')})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %% [markdown]
# ![alt text](https://sv1.picz.in.th/images/2019/01/23/T7R7lW.png)

# %% [markdown]
# # Find file ID from folder ID
# <pre>
# <code>
# file_list = drive.ListFile({'q': " 'folder_id' in parents and trashed=false"}).GetList()
# for file1 in file_list:
#   print('title: %s, id: %s' % (file1['title'], file1['id']))
# </code>
# </pre>
#
# ##the output of this code is file id in the folder id.

# %%
file_list = drive.ListFile({'q': "'1k9GJzwR-Eh4l2t-632VSGF5e7PhzwFiw' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))

# %% [markdown]
# <pre>
# title: userLog_201801_201802_for_participants.csv, id: 19sNUEOYeqU33EWBMRKq65YydpgLQoppZ
# title: project_facility, id: 1x1YF-rSwDOJo0azLKOHaBbQJLVK2lm5gd5F6VTUO5TA
# title: HW2_vistec.ipynb, id: 1x6UJEIiHtVpWzx7nJk9QaC9PNHimgHs5
# title: developer_main.csv, id: 1jjOrl2Dcw7AhsKPr2W4qU4LptkAkVbsV
# title: .ipynb_checkpoints, id: 1i--lYapijzU_OXizKPAL_7NIj_3aIOGu
# title: LICENSE.txt, id: 1AmTd7XUHyphsZ88dX5CAeqk6Qgn1MNBU
# title: Hackathon data dictionary.xlsx, id: 1k0-ve6O4TUBOAAG01XWGORtBpIZ7zXcP
# title: project_description.csv, id: 1y5tTE8nE_0GGclmSzsGZY4mfb1kArD1f
# title: project_main.csv, id: 1iRz0edC_tjIk0Ge33fKLZYN1ciXxup-0
# title: unit_type_id.csv, id: 1G-n9Bno_zyFL17ggRoaZIQZ7O9ph0CmR
# title: district_province_id.csv, id: 1ymd-812YyEyGs5exJnrKdWFnP15D0yFp
# title: facility_id.csv, id: 1eHh1ewhDPfwVhUQV5mplOkTmshg_ohNG
# title: developer_brand.csv, id: 1z0diuRz1VVnephPtrHo0kMs6dDqLqdxj
# title: project_unit.csv, id: 1L0VA6sAY7SiYlIoA8W6fObHZ0uHOi9-J
# title: project_facility.csv, id: 13jUinwDsk9sYvoMOBaTMfTM11912CvdO
# </pre>

# %% [markdown]
# #Example to download your file to colab
# ##make sure you import pandas  (import pandas as pd)
# <pre>
# <code>
#    train_downloaded = drive.CreateFile({'id': FILE_ID})
#    train_downloaded.GetContentFile('CSV_FILE.csv')
#    raw_dev_br = pd.read_csv('CSV_FILE.csv')
# </code>
# </pre>

# %%
import pandas as pd

developer_brand_downloaded = drive.CreateFile({'id': '1z0diuRz1VVnephPtrHo0kMs6dDqLqdxj'})
developer_brand_downloaded.GetContentFile('developer_brand.csv')
raw_dev_br = pd.read_csv('developer_brand.csv')
name_dev_br = raw_dev_br.columns.values[0].split(";")
print(name_dev_br)
print(raw_dev_br.columns.values[0])
raw_dev_br = raw_dev_br[raw_dev_br.columns.values[0]].str.split(";",expand = True) 
raw_dev_br.columns = name_dev_br
raw_dev_br.head()
# Out:
# ['developer_id', 'brand_id', 'brand_name_th', 'brand_name_en']
# developer_id;brand_id;brand_name_th;brand_name_en
#   developer_id brand_id                      brand_name_th brand_name_en
# 0          128      379                        เอสต้า บลิซ
# 1          176     1496  บริษัท ชัยยุทธ เรียล เอสเตท จำกัด
# 2          226     1819           "อะพูล คอนโด แอท บางนา "
# 3          143     1567           คาซ่า ฟรานซ์ เอแบค-บางนา
# 4          250      436                           เลอ นีโอ

# %%
def readDataFromDrive_HDT_single_col(file_id):
  # file_id is str
  data_downloaded = drive.CreateFile({'id': file_id })
  data_downloaded.GetContentFile('readCsvFile.csv')
  raw_data = pd.read_csv('readCsvFile.csv')
  name_dev_br = raw_data.columns.values[0].split(";")
  raw_data = raw_data[raw_data.columns.values[0]].str.split(";",expand = True) 
  raw_data.columns = name_dev_br
  print(raw_data.dtypes)
  raw_data.head()
  print('----------------------------------------------------------------------------------------------------------------------------')
  return raw_data;
  
def readDataFromDrive_HDT(file_id):
  # file_id is str
  data_downloaded = drive.CreateFile({'id': file_id })
  data_downloaded.GetContentFile('readCsvFile.csv')
  raw_data = pd.read_csv('readCsvFile.csv')
  print(raw_data.dtypes)
  raw_data.head()
  print('----------------------------------------------------------------------------------------------------------------------------')
  return raw_data;

# %%
developer_main = readDataFromDrive_HDT('1jjOrl2Dcw7AhsKPr2W4qU4LptkAkVbsV')
# Out:
# developer_id           int64
# developer_name_th     object
# developer_name_en     object
# description_th        object
# district_id          float64
# province_id          float64
# developer_status      object
# dtype: object
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <pre>
# <code>
# import pandas as pd
# train_downloaded = drive.CreateFile({'id': 'TRAIN_FILE_ID'})
# train_downloaded.GetContentFile('train.csv')
# df_train = pd.read_csv('train.csv')
# </code>
# </pre>

# %%
### load data ###############################################################################
developer_brand = "developer_brand.csv"

developer_main = "developer_main.csv"

district_province_id = "district_province_id.csv"

facility_id = "facility_id.csv"

#### don't know ###
# project_descrip = "project_description.csv"
# raw_proj_des = pd.read_csv(project_descrip)
# name_proj_des = raw_proj_des.columns.values[0] #.split(";")
# raw_fac_id = raw_fac_id[raw_fac_id.columns.values[0]].str.split(";",expand = True) 
# print('raw_proj_des')
# print(name_dev_br)
# print('#######################################')
###################

project_facility = "project_facility.csv"


project_main = "project_main.csv"

project_unit = "project_unit.csv"


unit_type_id = "unit_type_id.csv"


userLog = "userLog_201801_201802_for_participants.csv"

###  we selected data only 'Bangkok'
# province_id == 10
# Out:
# raw_dev_br
# ['developer_id', 'brand_id', 'brand_name_th', 'brand_name_en']
# #######################################
# raw_dev_main
# developer_id
# #######################################
# raw_dis_pro_id
# ['district_id', 'district_name_th', 'district_name_en', 'province_id', 'province_name_th', 'province_name_en']
# #######################################
# raw_fac_id
# ['facility_id', 'facility_name_th', 'facility_name_en']
# #######################################
# raw_proj_fac
# ['project_id', 'facility_id']
# #######################################
# raw_proj_main
# ['project_id', 'developer_id', 'brand_id', 'project_name_th', 'project_name_en', 'district_id', 'province_id', 'lat', 'lon', 'project_land_size_rai', 'project_land_size_ngan', 'project_land_size_wa', 'total_unit', 'percent_car_parking', 'starting_price', 'highest_price', 'project_status', 'created_at']
# #######################################
# raw_proj_unit
# ['project_id', 'unit_type_id', 'amount_bedroom', 'amount_bathroom', 'amount_car_parking', 'unit_starting_land_size', 'unit_highest_land_size', 'unit_functional_space_starting_size', 'unit_functional_space_highest_size', 'starting_price', 'highest_price', 'starting_price_per_area']
# #######################################
# raw_unit_type_id
# ['unit_type_id', 'unit_type_name_th', 'unit_type_name_en']
# #######################################
# raw_userLog
# ['userCode', 'project_id', 'requestedDevice', 'userAgent', 'pageReferrer', 'year', 'month', 'day', 'hour']
# #######################################

# %%
#############################################################################################
#############################################################################################
#### don't know ###
# project_descrip = "project_description.csv"
# raw_proj_des = pd.read_csv(project_descrip, error_bad_lines=False)
# name_proj_des = raw_proj_des.columns.values.split(";")
# raw_fac_id = raw_fac_id[raw_fac_id.columns.values].str.split(";",expand = True) 
# raw_fac_id.columns = name_proj_des
# print('raw_proj_des')
# print(name_proj_des)
# print('#######################################')
###################

# %%
# print(raw_proj_des.dtypes)
# raw_proj_des.head()

# %%
print(raw_dev_br.dtypes)
raw_dev_br['developer_id'] = raw_dev_br['developer_id'].astype('int')
raw_dev_br['brand_id'] = raw_dev_br['brand_id'].astype('int')
raw_dev_br['brand_name_th'] = raw_dev_br['brand_name_th'].astype('str')
raw_dev_br['brand_name_en'] = raw_dev_br['brand_name_en'].astype('str')
print(raw_dev_br.dtypes)
raw_dev_br.head()
# Out:
# developer_id     object
# brand_id         object
# brand_name_th    object
# brand_name_en    object
# dtype: object
# developer_id      int32
# brand_id          int32
# brand_name_th    object
# brand_name_en    object
# dtype: object
#    developer_id  brand_id                      brand_name_th brand_name_en
# 0           128       379                        เอสต้า บลิซ
# 1           176      1496  บริษัท ชัยยุทธ เรียล เอสเตท จำกัด
# 2           226      1819           "อะพูล คอนโด แอท บางนา "
# 3           143      1567           คาซ่า ฟรานซ์ เอแบค-บางนา
# 4           250       436                           เลอ นีโอ

# %%
print(raw_dev_main.dtypes)
print(raw_dev_main['province_id'].isnull().sum())
raw_dev_main = raw_dev_main.dropna(subset=['province_id'])
raw_dev_main['province_id'] = raw_dev_main['province_id'].astype('int')
# raw_dev_main['district_id'] = raw_dev_main['district_id'].astype('int')
print(raw_dev_main['district_id'].isnull().sum())
raw_dev_main = raw_dev_main.loc[raw_dev_main['province_id'] == 10] 
# work
# 
# used_dev_main['province_id'] = used_dev_main['province_id'].apply(np.int64)
# raw_dev_main.drop(raw_dev_main.loc[raw_dev_main['province_id'].isnull()])
# print(raw_dev_main['province_id'].isnull().sum())
# raw_dev_main.head()
raw_dev_main.head()
# Out:
# developer_id           int64
# developer_name_th     object
# developer_name_en     object
# description_th        object
# district_id          float64
# province_id            int32
# developer_status      object
# dtype: object
# 0
# 123
#     developer_id                                  developer_name_th  \
# 3            572     บริษัท ลุมพินี พร็อพเพอร์ตี้ แมเนจเม้นท์ จำกัด
# 4            679                 บริษัท ออพติโม พร็อพเพอร์ตี้ จำกัด
# 6            492  บริษัท พี.พี.เอส พร็อพเพอร์ตี้ ดีเวลลอปเม้นท์ ...
# 8            632                         บริษัท เอกมัย แอสเซท จำกัด
# 13           882                        บริษัท เค.เอส.ที.อาร์ จำกัด
#
#                       developer_name_en     description_th  district_id  \
# 3   Lumpini Property Management Co.,Ltd  บริษัทพัฒนาที่ดิน       1028.0
# 4                                   NaN  บริษัทพัฒนาที่ดิน       1044.0
# 6                                   NaN                NaN       1030.0
# 8                                   NaN  บริษัทพัฒนาที่ดิน       1039.0
# 13                                  NaN                NaN       1033.0
#
#     province_id developer_status
# 3            10                A
# 4            10                A
# 6            10                A
# 8            10                A
# 13           10                A

# %%
raw_dev_main.describe()
# Out:
#         developer_id  district_id  province_id
# count     709.000000   659.000000        709.0
# mean    64949.418900  1026.028832         10.0
# std     63852.726323    13.749852          0.0
# min       143.000000  1001.000000         10.0
# 25%      9188.000000  1014.000000         10.0
# 50%     18582.000000  1029.000000         10.0
# 75%    139718.000000  1038.000000         10.0
# max    141051.000000  1050.000000         10.0

# %%
print(raw_dis_pro_id.dtypes)
raw_dis_pro_id = raw_dis_pro_id.loc[raw_dis_pro_id['province_name_en'] == 'Bangkok']
raw_dis_pro_id['district_id'] = raw_dis_pro_id['district_id'].astype('int')
raw_dis_pro_id['province_id'] = raw_dis_pro_id['province_id'].astype('int')
raw_dis_pro_id.head()
# Out:
# district_id          int32
# district_name_th    object
# district_name_en    object
# province_id          int32
# province_name_th    object
# province_name_en    object
# dtype: object
#    district_id   district_name_th     district_name_en  province_id  \
# 0         1001             พระนคร          Phra Nakhon           10
# 1         1002              ดุสิต                Dusit           10
# 2         1008  ป้อมปราบศัตรูพ่าย  Pom Prap Sattruphai           10
# 3         1013        สัมพันธวงศ์       Samphanthawong           10
# 4         1004             บางรัก             Bang Rak           10
#
#   province_name_th province_name_en
# 0    กรุงเทพมหานคร          Bangkok
# 1    กรุงเทพมหานคร          Bangkok
# 2    กรุงเทพมหานคร          Bangkok
# 3    กรุงเทพมหานคร          Bangkok
# 4    กรุงเทพมหานคร          Bangkok

# %%
print(raw_fac_id.dtypes)
raw_fac_id.head()
# Out:
#   facility_id      facility_name_th facility_name_en
# 0           1            สระว่ายน้ำ    swimming_pool
# 1           2            คลับเฮ้าส์        clubhouse
# 2           3            สวนสาธารณะ             park
# 3           4                ฟิตเนส          fitness
# 4           5  ระบบรักษาความปลอดภัย  security_system

# %%
raw_fac_id.describe()
# Out:
#        facility_id facility_name_th facility_name_en
# count            6                6                6
# unique           6                6                6
# top              5     สนามเด็กเล่น       playground
# freq             1                1                1

# %%
#### don't know ###
# project_description = "project_description.csv"
# raw_proj_des = pd.read_csv(project_description)
# name_proj_des = raw_proj_des.columns.values[0] #.split(";")
# raw_fac_id = raw_fac_id[raw_fac_id.columns.values[0]].str.split(";",expand = True) 
# print('raw_proj_des')
# print(name_dev_br)
# print('#######################################')
# raw_proj_des.head()
# raw_proj_des.describe()
###################

# %%
print(raw_proj_fac.dtypes)
raw_proj_fac.head()
# Out:
#   project_id facility_id
# 0          4           1
# 1          4           3
# 2          4           4
# 3          4           5
# 4         45           2

# %%
raw_proj_fac.describe()
# Out:
#        project_id facility_id
# count       16070       16070
# unique       5039           6
# top          9035           5
# freq            6        4738

# %%
print(raw_proj_main.dtypes)
print(raw_proj_main['province_id'].isnull().sum())
raw_proj_main['province_id'] = raw_proj_main['province_id'].astype('int')
# proj_id
raw_proj_main['project_id'] = raw_proj_main['project_id'].astype('int')
# dev_id
raw_proj_main['developer_id'] = raw_proj_main['developer_id'].astype('int')
# district_id
raw_proj_main = raw_proj_main.loc[raw_proj_main['province_id'] == 10]
raw_proj_main.head()
# Out:
# project_id                object
# developer_id              object
# brand_id                  object
# project_name_th           object
# project_name_en           object
# district_id               object
# province_id                int32
# lat                       object
# lon                       object
# project_land_size_rai     object
# project_land_size_ngan    object
# project_land_size_wa      object
# total_unit                object
# percent_car_parking       object
# starting_price            object
# highest_price             object
# project_status            object
# created_at                object
# project_id                 int32
# dtype: object
# 0
#     project_id  developer_id brand_id                    project_name_th  \
# 0           44        140786        0                       พาร์ควิลล์ 3
# 1           24          1032        0                  สัมมากร นิมิตใหม่
# 7          208         13323             ลิฟวิ่งนารา รามคำแหง-สุวรรณภูมิ
# 8          228          6772        0  เค.ซี.รามอินทรา 5 (พระยาสุเรนทร์)
# 11         982         12136      979                อนาวิลล์ สุวรรณภูมิ
#
#                           project_name_en district_id  province_id  \
# 0                             Parkville 3        1046           10
# 1                      Sammakorn Nimitmai        1046           10
# 7   LIVING NARA RAMKHAMHAENG-SUVARNABHUMI        1011           10
# 8                         K.C. RAMINTRA 5        1046           10
# 11                  Anaville Suvarnabhumi        1011           10
#
#                 lat               lon project_land_size_rai  \
# 0        13.8917186       100.7220995                    54
# 1        13.8765900       100.7319273                   154
# 7          13.76981         100.72204                    44
# 8     13.8626235000    100.6951353000                    34
# 11  13.763347600000  100.803434300000                   131
#
#    project_land_size_ngan project_land_size_wa total_unit percent_car_parking  \
# 0                       0                    0
# 1                       3                   89
# 7                       0                   70        201
# 8                       2                   66
# 11                      2                    8
#
#    starting_price highest_price project_status                    created_at  \
# 0       3500000.0     3862000.0              A  2011-01-14T18:40:12.117+0700
# 1       4590000.0                            U  2011-02-24T21:43:59.297+0700
# 7       3500000.0     7600000.0              U  2010-07-02T07:00:00.000+0700
# 8       1810000.0                            U  2010-12-16T18:51:42.173+0700
# 11      4300000.0                            A  2011-01-17T22:55:47.317+0700
#
#     project_id
# 0            44
# 1            24
# 7           208
# 8           228
# 11          982

# %%
raw_proj_main.describe()
# Out:
#        province_id
# count       1775.0
# mean          10.0
# std            0.0
# min           10.0
# 25%           10.0
# 50%           10.0
# 75%           10.0
# max           10.0

# %%
raw_proj_unit.describe()
# Out:
#        project_id unit_type_id amount_bedroom amount_bathroom  \
# count       13745        13745          13745           13745
# unique       5379            6             11              13
# top          6531            3              3               2
# freq           71         5429           4804            3574
#
#        amount_car_parking unit_starting_land_size unit_highest_land_size  \
# count               13745                   13745                  13745
# unique                 13                     496                    228
# top
# freq                 6739                    9762                  12851
#
#        unit_functional_space_starting_size unit_functional_space_highest_size  \
# count                                13745                              13745
# unique                                2021                                820
# top
# freq                                  2832                              11771
#
#        starting_price highest_price starting_price_per_area
# count           13745         13745                   13745
# unique            577           132                      87
# top
# freq            11804         13502                   13646

# %%
print(raw_unit_type_id.dtypes)
raw_unit_type_id.head()
# Out:
#   unit_type_id unit_type_name_th    unit_type_name_en
# 0            1        บ้านเดี่ยว       Detached_House
# 1            2           บ้านแฝด  Semi_Detached_House
# 2            3      คอนโดมิเนียม          Condominium
# 3            4          ทาวน์โฮม             Townhome
# 4            5         โฮมออฟฟิส          Home_Office

# %%
print(raw_userLog.dtypes)
raw_userLog.head()
# Out:
#                                userCode project_id requestedDevice userAgent  \
# 0  7717bdc2-ea3e-e8ad-5d6b-178bd71c38b2       7956          Mobile   Android
# 1  7717bdc2-ea3e-e8ad-5d6b-178bd71c38b2       7956          Mobile   Android
# 2  cb5b4b68-cc01-6db6-f54b-4a0f881301c5       5067          Mobile    iPhone
# 3  5f74cef2-0d1e-b619-3564-0955a14e0985       6654          Mobile    iPhone
# 4  dba8f279-844e-eef6-73ac-22bd7d1353cc       6474          Mobile      iPad
#
#   pageReferrer  year month day hour
# 0  HomeWebsite  2018     1   1    0
# 1  HomeWebsite  2018     1   1    0
# 2  HomeWebsite  2018     1   1    0
# 3       Google  2018     1   1    0
# 4       Google  2018     1   1    0

# %%
raw_userLog.describe()
# Out:
#                                     userCode project_id requestedDevice  \
# count                                1234579    1234579         1234579
# unique                                482751       5395               2
# top     de89bac5-57c6-ecfb-184d-cc4e973c31ac       5858          Mobile
# freq                                   24308       7186          747784
#
#        userAgent pageReferrer     year    month      day     hour
# count    1234579      1234579  1234579  1234579  1234579  1234579
# unique         6            4        1        2       31       24
# top      Windows       Google     2018        1       22       15
# freq      415784       651633  1234579   706247    56354    86806
