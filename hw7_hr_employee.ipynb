# %% [markdown]
# <a href="https://colab.research.google.com/github/Pataweepr/applyML_vistec_2019/blob/master/hw7_hr_employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [link text](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

import pandas as pd

# %%
file_list = drive.ListFile({'q': "'1A4hVTSdT-5xpsieZ1MQI78eio1lSmTea' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: hr-employee-attrition-with-null.csv, id: 1VDImQ1SDFz3kG2hyUdUfGLOmEpDs7A16
# title: HW2_Attrition_Prediction.pdf, id: 1oEY-4s7VFViEx7_RspTtVklKrQ6TsOT4

# %%
train_downloaded = drive.CreateFile({'id': '1VDImQ1SDFz3kG2hyUdUfGLOmEpDs7A16'})
train_downloaded.GetContentFile('CSV_FILE.csv')
hr_data = pd.read_csv('CSV_FILE.csv')
hr_data.head(10)
# Out:
#    Unnamed: 0   Age Attrition     BusinessTravel  DailyRate  \
# 0           0  41.0       Yes      Travel_Rarely        NaN
# 1           1   NaN        No                NaN      279.0
# 2           2  37.0       Yes                NaN     1373.0
# 3           3   NaN        No  Travel_Frequently     1392.0
# 4           4  27.0        No      Travel_Rarely      591.0
# 5           5  32.0        No                NaN     1005.0
# 6           6   NaN        No                NaN        NaN
# 7           7  30.0        No      Travel_Rarely     1358.0
# 8           8  38.0        No  Travel_Frequently      216.0
# 9           9   NaN        No      Travel_Rarely     1299.0
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                     NaN               1.0        NaN  Life Sciences
# 1  Research & Development               NaN        NaN  Life Sciences
# 2                     NaN               2.0        2.0            NaN
# ...
